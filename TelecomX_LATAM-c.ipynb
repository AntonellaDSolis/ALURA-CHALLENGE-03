# %% [markdown]
# #📌 Extracción

# %%
import json
import requests
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

url = 'https://raw.githubusercontent.com/alura-cursos/challenge2-data-science-LATAM/main/TelecomX_Data.json'
response = requests.get(url)
data = response.json()
df = pd.json_normalize(data)

# %% [markdown]
# #🔧 Transformación

# %%
df = pd.DataFrame(datos)

df.head()

df.columns = df.columns.str.replace('.', '_')

df.isnull().sum()

df["account_Charges_Total"] = pd.to_numeric(
    df["account_Charges_Total"],
    errors="coerce"
)

df = df.dropna()

# %% [markdown]
# #📊 Carga y análisis

# %% [markdown]
# #📄Informe final

# %%
En este proyecto se desarrolló un proceso completo de ETL (Extract, Transform, Load) utilizando Python.

Los datos fueron extraídos desde un archivo JSON proveniente de una API, el cual presentaba una estructura jerárquica con múltiples niveles de información. Durante la etapa de transformación se realizó la normalización de las estructuras anidadas para convertir los datos en un formato tabular adecuado para análisis.

Posteriormente se aplicaron procesos de limpieza, incluyendo la conversión de variables numéricas, tratamiento de valores nulos y estandarización de nombres de columnas.

Como resultado, se generó un dataset limpio y estructurado que permite realizar análisis posteriores sobre el comportamiento de los clientes, los servicios contratados y posibles factores asociados a la cancelación de servicios.

Este proceso demuestra la importancia de las etapas de preparación de datos dentro del flujo de trabajo de análisis de datos, ya que la calidad y estructura del dataset influyen directamente en la capacidad de generar insights confiables.
